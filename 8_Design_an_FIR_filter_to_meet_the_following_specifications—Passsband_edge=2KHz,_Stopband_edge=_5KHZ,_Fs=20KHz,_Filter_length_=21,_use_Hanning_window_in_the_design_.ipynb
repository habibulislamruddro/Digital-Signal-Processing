# %% [markdown]
# <a href="https://colab.research.google.com/github/habibulislamruddro/Digital-Signal-Processing/blob/main/8_Design_an_FIR_filter_to_meet_the_following_specifications%E2%80%94Passsband_edge%3D2KHz%2C_Stopband_edge%3D_5KHZ%2C_Fs%3D20KHz%2C_Filter_length_%3D21%2C_use_Hanning_window_in_the_design_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.signal import firwin,freqz
import matplotlib.pyplot as plt

# %%
pass_band = 2000
stop = 5000
fs1 = 20000
filter_length = 21

# %%
tap = firwin(filter_length, pass_band,width=stop-pass_band,pass_zero='lowpass',fs=fs1,window='hann')

response = freqz(tap, worN=8000)

# %%
plt.plot(fs1*.5*response[0]/(np.pi), np.abs(response[1]))
plt.grid()
plt.show()
