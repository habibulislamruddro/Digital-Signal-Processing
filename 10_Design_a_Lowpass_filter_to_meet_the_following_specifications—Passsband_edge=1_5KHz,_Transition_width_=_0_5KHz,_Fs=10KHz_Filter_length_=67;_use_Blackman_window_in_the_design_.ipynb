# %% [markdown]
# <a href="https://colab.research.google.com/github/habibulislamruddro/Digital-Signal-Processing/blob/main/10_Design_a_Lowpass_filter_to_meet_the_following_specifications%E2%80%94Passsband_edge%3D1_5KHz%2C_Transition_width_%3D_0_5KHz%2C_Fs%3D10KHz_Filter_length_%3D67%3B_use_Blackman_window_in_the_design_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.signal import firwin,freqz
import matplotlib.pyplot as plt
import scipy.signal as signal

# %%
pass_band = 1500
tran_width = 500
fs = 10000
filter_length = 67

# %%
taps = signal.firwin(67,pass_band,fs=fs,pass_zero='lowpass',window='blackman',width=tran_width)
response = signal.freqz(taps,worN=8000)

# %%
plt.plot(fs*response[0]/2/np.pi,np.abs(response[1]))
plt.grid()
